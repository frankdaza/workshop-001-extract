# %% [markdown]
# ## 1. Read the data from the CSV file

# %% [markdown]
# #### 1.1 Running imports:

# %%
import os
from dotenv import load_dotenv
import psycopg2
from sqlalchemy import create_engine, text
import pandas as pd

# %% [markdown]
# #### 1.2 Load database credentials from environment variables:

# %%
load_dotenv()

db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
db_port = int(os.getenv("DB_PORT", 5432))
db_name = os.getenv("DB_NAME")

if db_user is None:
    raise ValueError("DB_USER is not set")
if db_password is None:
    raise ValueError("DB_PASSWORD is not set")
if db_host is None:
    raise ValueError("DB_HOST is not set")
if db_port is None:
    raise ValueError("DB_PORT is not set")
if db_name is None:
    raise ValueError("DB_NAME is not set")

conn = psycopg2.connect(
    dbname=db_name,
    user=db_user,
    password=db_password,
    host=db_host,
    port=db_port
)
conn.autocommit = True

# %% [markdown]
# #### 1.3 Read the CSV file:

# %%
df_candidates = pd.read_csv("candidates.csv", delimiter=";", skiprows=1)

# Rename columns after loading the data
df_candidates.columns = ["first_name", "last_name", "email", "application_date", "country", "yoe", "seniority", "technology", "code_challenge_score", "technical_interview_score"]

# Just print the first 20 rows to test
df_candidates.head(20)
# Out:
#    first_name    last_name                      email application_date  \
# 0      Camryn     Reynolds        zelda56@hotmail.com       2021-09-09
# 1       Larue       Spinka   okey_schultz41@gmail.com       2020-04-14
# 2        Arch       Spinka     elvera_kulas@yahoo.com       2020-10-01
# 3       Larue   Altenwerth  minnie.gislason@gmail.com       2020-05-20
# 4        Alec       Abbott   juanita_hansen@gmail.com       2019-08-17
# 5     Allison       Jacobs   alba_rolfson27@yahoo.com       2018-05-18
# 6         Nya       Skiles   madisen.zulauf@gmail.com       2021-12-09
# 7        Mose        Lakin   dale_murazik@hotmail.com       2018-03-13
# 8    Terrance        Zieme       dustin31@hotmail.com       2022-04-08
# 9      Aiyana      Goodwin    vallie.damore@yahoo.com       2019-09-22
# 10     Emilia      Waelchi      peter.grady@gmail.com       2020-07-15
# 11    Terrell      Streich           meta92@yahoo.com       2021-12-27
# 12      Hilda    Rodriguez   jordan.hyatt@hotmail.com       2020-05-09
# 13       Hope       Hansen  clemmie.bruen@hotmail.com       2019-10-12
# 14       Arno   Altenwerth    cheyenne_rau2@gmail.com       2018-10-18
# 15      Betty        Crona    judd.wisozk55@gmail.com       2020-03-25
# 16      Clint  Oberbrunner  dwight_jacobson@gmail.com       2021-05-23
# 17      Donny        Boehm       lucile97@hotmail.com       2018-05-02
# 18       Adah       Pouros          derick1@gmail.com       2021-04-13
# 19     Winona      Zboncak          doyle78@yahoo.com       2019-03-21
#
#                         country  yoe  seniority  \
# 0                        Panama   10     Intern
# 1                       Belarus    4  Mid-Level
# 2                       Eritrea   25    Trainee
# 3                       Myanmar   13  Mid-Level
# 4                      Zimbabwe    8     Junior
# 5             Wallis and Futuna   19    Trainee
# 6                       Myanmar    1       Lead
# 7                         Italy   18       Lead
# 8                   Timor-Leste   25       Lead
# 9                       Armenia   24     Intern
# 10  French Southern Territories   28       Lead
# 11                         Chad    3  Mid-Level
# 12                  El Salvador   16     Junior
# 13                   Mozambique   18  Architect
# 14            Brunei Darussalam   21  Mid-Level
# 15                      Morocco   28  Architect
# 16                 Saint Helena   19     Senior
# 17                     Portugal   20    Trainee
# 18                   Mozambique    3  Architect
# 19     Central African Republic   29  Architect
#
#                            technology  code_challenge_score  \
# 0                       Data Engineer                     2
# 1                      Client Success                    10
# 2                           QA Manual                     7
# 3   Social Media Community Management                     9
# 4            Adobe Experience Manager                     2
# 5                               Sales                     2
# 6                            Mulesoft                     2
# 7   Social Media Community Management                     7
# 8                              DevOps                     2
# 9           Development - CMS Backend                     4
# 10                             DevOps                     7
# 11                         Salesforce                     5
# 12              System Administration                     7
# 13                           Security                     4
# 14                   Game Development                     4
# 15  Social Media Community Management                     5
# 16  Social Media Community Management                     3
# 17         Development - CMS Frontend                     4
# 18           Adobe Experience Manager                     2
# 19                   Game Development                     0
#
#     technical_interview_score
# 0                          10
# 1                           9
# 2                           1
# 3                           7
# 4                           9
# 5                           9
# 6                           5
# 7                          10
# 8                           0
# 9                           9
# 10                          4
# 11                         10
# 12                          8
# 13                          1
# 14                          6
# 15                          5
# 16                          5
# 17                          2
# 18                          3
# 19                          2

# %% [markdown]
# # 2. Load the data into the database (staging area):

# %% [markdown]
# #### 2.1 Create the database engine:

# %%
db_engine = create_engine(f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}")

# %% [markdown]
# #### 2.2 Store the CSV file data into a PostgreSQL database:

# %%
with db_engine.connect() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS candidates (
            first_name CHARACTER VARYING,
            last_name CHARACTER VARYING,
            email CHARACTER VARYING,
            application_date DATE,
            country CHARACTER VARYING,
            yoe INTEGER,
            seniority CHARACTER VARYING,
            technology CHARACTER VARYING,
            code_challenge_score INTEGER,
            technical_interview_score INTEGER
        );
    """))
    conn.commit()
    print("Table 'candidates' created successfully.")

# Store DataFrame into PostgreSQL table named 'candidates'
df_candidates.to_sql("candidates", db_engine, if_exists="append", index=False)

print("The CSV file data was inserted successfully!")
# Out:
# Table 'candidates' created successfully.
# The CSV file data was inserted successfully!

# %% [markdown]
# # 3. Read the table that was created with Python:

# %%
# Just print the first 20 rows to test
df_verification = pd.read_sql("SELECT * FROM candidates LIMIT 20;", db_engine)
df_verification
# Out:
#    first_name    last_name                      email application_date  \
# 0      Camryn     Reynolds        zelda56@hotmail.com       2021-09-09
# 1       Larue       Spinka   okey_schultz41@gmail.com       2020-04-14
# 2        Arch       Spinka     elvera_kulas@yahoo.com       2020-10-01
# 3       Larue   Altenwerth  minnie.gislason@gmail.com       2020-05-20
# 4        Alec       Abbott   juanita_hansen@gmail.com       2019-08-17
# 5     Allison       Jacobs   alba_rolfson27@yahoo.com       2018-05-18
# 6         Nya       Skiles   madisen.zulauf@gmail.com       2021-12-09
# 7        Mose        Lakin   dale_murazik@hotmail.com       2018-03-13
# 8    Terrance        Zieme       dustin31@hotmail.com       2022-04-08
# 9      Aiyana      Goodwin    vallie.damore@yahoo.com       2019-09-22
# 10     Emilia      Waelchi      peter.grady@gmail.com       2020-07-15
# 11    Terrell      Streich           meta92@yahoo.com       2021-12-27
# 12      Hilda    Rodriguez   jordan.hyatt@hotmail.com       2020-05-09
# 13       Hope       Hansen  clemmie.bruen@hotmail.com       2019-10-12
# 14       Arno   Altenwerth    cheyenne_rau2@gmail.com       2018-10-18
# 15      Betty        Crona    judd.wisozk55@gmail.com       2020-03-25
# 16      Clint  Oberbrunner  dwight_jacobson@gmail.com       2021-05-23
# 17      Donny        Boehm       lucile97@hotmail.com       2018-05-02
# 18       Adah       Pouros          derick1@gmail.com       2021-04-13
# 19     Winona      Zboncak          doyle78@yahoo.com       2019-03-21
#
#                         country  yoe  seniority  \
# 0                        Panama   10     Intern
# 1                       Belarus    4  Mid-Level
# 2                       Eritrea   25    Trainee
# 3                       Myanmar   13  Mid-Level
# 4                      Zimbabwe    8     Junior
# 5             Wallis and Futuna   19    Trainee
# 6                       Myanmar    1       Lead
# 7                         Italy   18       Lead
# 8                   Timor-Leste   25       Lead
# 9                       Armenia   24     Intern
# 10  French Southern Territories   28       Lead
# 11                         Chad    3  Mid-Level
# 12                  El Salvador   16     Junior
# 13                   Mozambique   18  Architect
# 14            Brunei Darussalam   21  Mid-Level
# 15                      Morocco   28  Architect
# 16                 Saint Helena   19     Senior
# 17                     Portugal   20    Trainee
# 18                   Mozambique    3  Architect
# 19     Central African Republic   29  Architect
#
#                            technology  code_challenge_score  \
# 0                       Data Engineer                     2
# 1                      Client Success                    10
# 2                           QA Manual                     7
# 3   Social Media Community Management                     9
# 4            Adobe Experience Manager                     2
# 5                               Sales                     2
# 6                            Mulesoft                     2
# 7   Social Media Community Management                     7
# 8                              DevOps                     2
# 9           Development - CMS Backend                     4
# 10                             DevOps                     7
# 11                         Salesforce                     5
# 12              System Administration                     7
# 13                           Security                     4
# 14                   Game Development                     4
# 15  Social Media Community Management                     5
# 16  Social Media Community Management                     3
# 17         Development - CMS Frontend                     4
# 18           Adobe Experience Manager                     2
# 19                   Game Development                     0
#
#     technical_interview_score
# 0                          10
# 1                           9
# 2                           1
# 3                           7
# 4                           9
# 5                           9
# 6                           5
# 7                          10
# 8                           0
# 9                           9
# 10                          4
# 11                         10
# 12                          8
# 13                          1
# 14                          6
# 15                          5
# 16                          5
# 17                          2
# 18                          3
# 19                          2

# %% [markdown]
# # 4. Do some transformations:

# %% [markdown]
# #### 4.1 Create a copy of the candidates data frame and add the hired column:

# %%
df_candidates_transformed = df_candidates.copy()
df_candidates_transformed["hired"] = df_candidates_transformed.apply(
    lambda x: "Yes" if x["code_challenge_score"] >= 7 and x["technical_interview_score"] >= 7 else "No",
    axis=1
) 

# Just print the first 20 rows to test
df_candidates_transformed.head(20)
# Out:
#    first_name    last_name                      email application_date  \
# 0      Camryn     Reynolds        zelda56@hotmail.com       2021-09-09
# 1       Larue       Spinka   okey_schultz41@gmail.com       2020-04-14
# 2        Arch       Spinka     elvera_kulas@yahoo.com       2020-10-01
# 3       Larue   Altenwerth  minnie.gislason@gmail.com       2020-05-20
# 4        Alec       Abbott   juanita_hansen@gmail.com       2019-08-17
# 5     Allison       Jacobs   alba_rolfson27@yahoo.com       2018-05-18
# 6         Nya       Skiles   madisen.zulauf@gmail.com       2021-12-09
# 7        Mose        Lakin   dale_murazik@hotmail.com       2018-03-13
# 8    Terrance        Zieme       dustin31@hotmail.com       2022-04-08
# 9      Aiyana      Goodwin    vallie.damore@yahoo.com       2019-09-22
# 10     Emilia      Waelchi      peter.grady@gmail.com       2020-07-15
# 11    Terrell      Streich           meta92@yahoo.com       2021-12-27
# 12      Hilda    Rodriguez   jordan.hyatt@hotmail.com       2020-05-09
# 13       Hope       Hansen  clemmie.bruen@hotmail.com       2019-10-12
# 14       Arno   Altenwerth    cheyenne_rau2@gmail.com       2018-10-18
# 15      Betty        Crona    judd.wisozk55@gmail.com       2020-03-25
# 16      Clint  Oberbrunner  dwight_jacobson@gmail.com       2021-05-23
# 17      Donny        Boehm       lucile97@hotmail.com       2018-05-02
# 18       Adah       Pouros          derick1@gmail.com       2021-04-13
# 19     Winona      Zboncak          doyle78@yahoo.com       2019-03-21
#
#                         country  yoe  seniority  \
# 0                        Panama   10     Intern
# 1                       Belarus    4  Mid-Level
# 2                       Eritrea   25    Trainee
# 3                       Myanmar   13  Mid-Level
# 4                      Zimbabwe    8     Junior
# 5             Wallis and Futuna   19    Trainee
# 6                       Myanmar    1       Lead
# 7                         Italy   18       Lead
# 8                   Timor-Leste   25       Lead
# 9                       Armenia   24     Intern
# 10  French Southern Territories   28       Lead
# 11                         Chad    3  Mid-Level
# 12                  El Salvador   16     Junior
# 13                   Mozambique   18  Architect
# 14            Brunei Darussalam   21  Mid-Level
# 15                      Morocco   28  Architect
# 16                 Saint Helena   19     Senior
# 17                     Portugal   20    Trainee
# 18                   Mozambique    3  Architect
# 19     Central African Republic   29  Architect
#
#                            technology  code_challenge_score  \
# 0                       Data Engineer                     2
# 1                      Client Success                    10
# 2                           QA Manual                     7
# 3   Social Media Community Management                     9
# 4            Adobe Experience Manager                     2
# 5                               Sales                     2
# 6                            Mulesoft                     2
# 7   Social Media Community Management                     7
# 8                              DevOps                     2
# 9           Development - CMS Backend                     4
# 10                             DevOps                     7
# 11                         Salesforce                     5
# 12              System Administration                     7
# 13                           Security                     4
# 14                   Game Development                     4
# 15  Social Media Community Management                     5
# 16  Social Media Community Management                     3
# 17         Development - CMS Frontend                     4
# 18           Adobe Experience Manager                     2
# 19                   Game Development                     0
#
#     technical_interview_score hired
# 0                          10    No
# 1                           9   Yes
# 2                           1    No
# 3                           7   Yes
# 4                           9    No
# 5                           9    No
# 6                           5    No
# 7                          10   Yes
# 8                           0    No
# 9                           9    No
# 10                          4    No
# 11                         10    No
# 12                          8   Yes
# 13                          1    No
# 14                          6    No
# 15                          5    No
# 16                          5    No
# 17                          2    No
# 18                          3    No
# 19                          2    No

# %% [markdown]
# # 5. Load the transformed data into a new 'transformed_candidates' table:

# %% [markdown]
# ##### 5.1 Create the new 'transformed_candidates' table:

# %%
with db_engine.connect() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS transformed_candidates (
            first_name CHARACTER VARYING,
            last_name CHARACTER VARYING,
            email CHARACTER VARYING,
            application_date DATE,
            country CHARACTER VARYING,
            yoe INTEGER,
            seniority CHARACTER VARYING,
            technology CHARACTER VARYING,
            code_challenge_score INTEGER,
            technical_interview_score INTEGER,
            hired BOOLEAN
        );
    """))
    conn.commit()
    print("Table 'transformed_candidates' created successfully.")

# Store DataFrame into PostgreSQL table named 'candidates'
df_candidates_transformed.to_sql("transformed_candidates", db_engine, if_exists="append", index=False)
# Out:
# Table 'transformed_candidates' created successfully.
# 999

# %% [markdown]
# #### 5.2 Read the information from the new 'transformed_candidates' table:

# %%
# Just print the first 20 rows to test
df_transformed_verification = pd.read_sql("SELECT * FROM transformed_candidates LIMIT 20;", db_engine)
df_transformed_verification
# Out:
#    first_name    last_name                      email application_date  \
# 0      Camryn     Reynolds        zelda56@hotmail.com       2021-09-09
# 1       Larue       Spinka   okey_schultz41@gmail.com       2020-04-14
# 2        Arch       Spinka     elvera_kulas@yahoo.com       2020-10-01
# 3       Larue   Altenwerth  minnie.gislason@gmail.com       2020-05-20
# 4        Alec       Abbott   juanita_hansen@gmail.com       2019-08-17
# 5     Allison       Jacobs   alba_rolfson27@yahoo.com       2018-05-18
# 6         Nya       Skiles   madisen.zulauf@gmail.com       2021-12-09
# 7        Mose        Lakin   dale_murazik@hotmail.com       2018-03-13
# 8    Terrance        Zieme       dustin31@hotmail.com       2022-04-08
# 9      Aiyana      Goodwin    vallie.damore@yahoo.com       2019-09-22
# 10     Emilia      Waelchi      peter.grady@gmail.com       2020-07-15
# 11    Terrell      Streich           meta92@yahoo.com       2021-12-27
# 12      Hilda    Rodriguez   jordan.hyatt@hotmail.com       2020-05-09
# 13       Hope       Hansen  clemmie.bruen@hotmail.com       2019-10-12
# 14       Arno   Altenwerth    cheyenne_rau2@gmail.com       2018-10-18
# 15      Betty        Crona    judd.wisozk55@gmail.com       2020-03-25
# 16      Clint  Oberbrunner  dwight_jacobson@gmail.com       2021-05-23
# 17      Donny        Boehm       lucile97@hotmail.com       2018-05-02
# 18       Adah       Pouros          derick1@gmail.com       2021-04-13
# 19     Winona      Zboncak          doyle78@yahoo.com       2019-03-21
#
#                         country  yoe  seniority  \
# 0                        Panama   10     Intern
# 1                       Belarus    4  Mid-Level
# 2                       Eritrea   25    Trainee
# 3                       Myanmar   13  Mid-Level
# 4                      Zimbabwe    8     Junior
# 5             Wallis and Futuna   19    Trainee
# 6                       Myanmar    1       Lead
# 7                         Italy   18       Lead
# 8                   Timor-Leste   25       Lead
# 9                       Armenia   24     Intern
# 10  French Southern Territories   28       Lead
# 11                         Chad    3  Mid-Level
# 12                  El Salvador   16     Junior
# 13                   Mozambique   18  Architect
# 14            Brunei Darussalam   21  Mid-Level
# 15                      Morocco   28  Architect
# 16                 Saint Helena   19     Senior
# 17                     Portugal   20    Trainee
# 18                   Mozambique    3  Architect
# 19     Central African Republic   29  Architect
#
#                            technology  code_challenge_score  \
# 0                       Data Engineer                     2
# 1                      Client Success                    10
# 2                           QA Manual                     7
# 3   Social Media Community Management                     9
# 4            Adobe Experience Manager                     2
# 5                               Sales                     2
# 6                            Mulesoft                     2
# 7   Social Media Community Management                     7
# 8                              DevOps                     2
# 9           Development - CMS Backend                     4
# 10                             DevOps                     7
# 11                         Salesforce                     5
# 12              System Administration                     7
# 13                           Security                     4
# 14                   Game Development                     4
# 15  Social Media Community Management                     5
# 16  Social Media Community Management                     3
# 17         Development - CMS Frontend                     4
# 18           Adobe Experience Manager                     2
# 19                   Game Development                     0
#
#     technical_interview_score  hired
# 0                          10  False
# 1                           9   True
# 2                           1  False
# 3                           7   True
# 4                           9  False
# 5                           9  False
# 6                           5  False
# 7                          10   True
# 8                           0  False
# 9                           9  False
# 10                          4  False
# 11                         10  False
# 12                          8   True
# 13                          1  False
# 14                          6  False
# 15                          5  False
# 16                          5  False
# 17                          2  False
# 18                          3  False
# 19                          2  False
